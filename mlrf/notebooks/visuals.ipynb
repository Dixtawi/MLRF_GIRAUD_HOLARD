# %% [markdown]
# # Visualisation

# %%
import sys
import os

library_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'library'))

if library_path not in sys.path:
    sys.path.append(library_path)

# %%
from modeling.models import models
from dataset import load_dataset
from features import hog_features
from plots import plot_roc_curves

# %%
X_train, X_test, y_train, y_test = load_dataset()
X_train_hog = hog_features(X_train)
X_test_hog = hog_features(X_test)

# %%
plot_roc_curves(models, X_train_hog, y_train, X_test_hog, y_test)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plot_roc_curves(models, X_train_hog, y_train, X_test_hog, y_test)
#
# File ~/Workspace/ING2/Projects/MLRF_GIRAUD_HOLARD/mlrf/library/plots.py:25, in plot_roc_curves(models, X_train, y_train, X_test, y_test)
#      22 model_clone = clone(model)
#      23 model_clone.fit(X_train, y_train)
# ---> 25 y_prob = model_clone.predict_proba(X_test)
#      27 fpr, tpr, roc_auc = {}, {}, {}
#      28 for i in range(y_test_bin.shape[1]):
#
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/_available_if.py:31, in _AvailableIfDescriptor.__get__(self, obj, owner)
#      25 attr_err = AttributeError(
#      26     f"This {repr(owner.__name__)} has no attribute {repr(self.attribute_name)}"
#      27 )
#      28 if obj is not None:
#      29     # delegate only on instances, not the classes.
#      30     # this is to allow access to the docstrings.
# ---> 31     if not self.check(obj):
#      32         raise attr_err
#      33     out = MethodType(self.fn, obj)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/svm/_base.py:827, in BaseSVC._check_proba(self)
#     825 def _check_proba(self):
#     826     if not self.probability:
# --> 827         raise AttributeError(
#     828             "predict_proba is not available when probability=False"
#     829         )
#     830     if self._impl not in ("c_svc", "nu_svc"):
#     831         raise AttributeError("predict_proba only implemented for SVC and NuSVC")
#
# AttributeError: predict_proba is not available when probability=False
