# %%
import sys
import os

library_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'library'))

if library_path not in sys.path:
    sys.path.append(library_path)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from dataset import load_dataset

# %%
# Charger les données de test
X_train, X_test, y_train, y_test = load_dataset()

# %%
# Créer un modèle de régression logistique
model = SVC(kernel='linear', random_state=42)
model2 = RandomForestClassifier(random_state=42)

# %%
# Entraîner le modèle
model.fit(X_train.reshape(len(X_train), -1), y_train)
model2.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
# Entraîner un modèle de régression logistique
model2 = LogisticRegression(random_state=42)
model2.fit(X, y)
# Out:
# LogisticRegression(random_state=42)

# %%
# Définir la grille pour la visualisation
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

# %%
# Prédire la classe pour chaque point dans la grille
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# %%
# Prédire la classe pour chaque point dans la grille 2
Z2 = model2.predict(np.c_[xx.ravel(), yy.ravel()])
Z2 = Z2.reshape(xx.shape)

# %%
# Tracer la carte de couleur et la frontière de décision
plt.contourf(xx, yy, Z, alpha=0.8)
plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k', cmap=plt.cm.Paired)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Decision Boundary')
plt.show()

# %%
# Tracer la carte de couleur et la frontière de décision 2
plt.contourf(xx, yy, Z2, alpha=0.8)
plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k', cmap=plt.cm.Paired)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Decision Boundary')
plt.show()
